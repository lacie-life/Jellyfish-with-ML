# %% [markdown]
# ## Data Exploration

# %%
import os
path2train = "./data/training_set/"

imgsList = [pp for pp in os.listdir(path2train) if "Annotation" not in pp]
anntsList = [pp for pp in os.listdir(path2train) if "Annotation" in pp]
print("number of images:", len(imgsList))
print("number of annotations:", len(anntsList))
# Out:
# number of images: 999
# number of annotations: 999

# %%
import numpy as np
np.random.seed(2019)
rndImgs = np.random.choice(imgsList,4)
rndImgs
# Out:
# array(['947_HC.png', '964_HC.png', '931_HC.png', '764_2HC.png'],
#       dtype='<U11')

# %%
# %pip install scikit-image
# %pip install fastcore -U
# Out:
# Requirement already satisfied: scikit-image in /home/lacie/miniconda3/envs/conda-pytorch/lib/python3.8/site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.21.1 in /home/lacie/.local/lib/python3.8/site-packages (from scikit-image) (1.24.3)
# Requirement already satisfied: scipy>=1.8 in /home/lacie/miniconda3/envs/conda-pytorch/lib/python3.8/site-packages (from scikit-image) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in /home/lacie/miniconda3/envs/conda-pytorch/lib/python3.8/site-packages (from scikit-image) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /home/lacie/miniconda3/envs/conda-pytorch/lib/python3.8/site-packages (from scikit-image) (9.0.1)
# Requirement already satisfied: imageio>=2.27 in /home/lacie/miniconda3/envs/conda-pytorch/lib/python3.8/site-packages (from scikit-image) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/lacie/miniconda3/envs/conda-pytorch/lib/python3.8/site-packages (from scikit-image) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/lacie/miniconda3/envs/conda-pytorch/lib/python3.8/site-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: packaging>=21 in /home/lacie/miniconda3/envs/conda-pytorch/lib/python3.8/site-packages (from scikit-image) (23.1)
# Requirement already satisfied: lazy_loader>=0.2 in /home/lacie/miniconda3/envs/conda-pytorch/lib/python3.8/site-packages (from scikit-image) (0.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: fastcore in /home/lacie/miniconda3/envs/conda-pytorch/lib/python3.8/site-packages (1.5.29)
# Requirement already satisfied: pip in /home/lacie/miniconda3/envs/conda-pytorch/lib/python3.8/site-packages (from fastcore) (23.2.1)
# Requirement already satisfied: packaging in /home/lacie/miniconda3/envs/conda-pytorch/lib/python3.8/site-packages (from fastcore) (23.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pillow==9.0.1
# Out:
# Requirement already satisfied: pillow==9.0.1 in /home/lacie/miniconda3/envs/conda-pytorch/lib/python3.8/site-packages (9.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pylab as plt
from PIL import Image
from scipy import ndimage as ndi
from skimage.segmentation import mark_boundaries
from torchvision.transforms.functional import to_tensor, to_pil_image
import torch

# %%
def show_img_mask(img, mask):
    if torch.is_tensor(img):
        img = to_pil_image(img)
        mask = to_pil_image(mask)
        
    img_mask = mark_boundaries(np.array(img), 
                        np.array(mask),
                        outline_color=(0,1,0),
                        color=(0,1,0))
    plt.imshow(img_mask)

# %%
for fn in rndImgs:
    path2img = os.path.join(path2train, fn)
    path2annt= path2img.replace(".png", "_Annotation.png")
    img = Image.open(path2img)
    annt_edges = Image.open(path2annt)
    mask = ndi.binary_fill_holes(annt_edges)        

    plt.figure()
    plt.subplot(1, 3, 1) 
    plt.imshow(img, cmap="gray")

    plt.subplot(1, 3, 2) 
    plt.imshow(mask, cmap="gray")

    plt.subplot(1, 3, 3) 
    show_img_mask(img, mask)

# %%
plt.figure()
plt.subplot(1, 3, 1) 
plt.imshow(img, cmap="gray")
plt.axis('off')

plt.subplot(1, 3, 2) 
plt.imshow(mask, cmap="gray")
plt.axis('off')    

plt.subplot(1, 3, 3) 
show_img_mask(img, mask)
plt.axis('off')
# Out:
# (-0.5, 799.5, 539.5, -0.5)

# %%
from albumentations import (
    HorizontalFlip,
    VerticalFlip,    
    Compose,
    Resize,
)

h,w = 128,192
transform_train = Compose([ Resize(h,w), 
                HorizontalFlip(p=0.5), 
                VerticalFlip(p=0.5), 
              ])


transform_val = Resize(h,w)

# %% [markdown]
# ## Creating Custom Dataset

# %%
from torch.utils.data import Dataset
from PIL import Image

# %%
from torchvision.transforms.functional import to_tensor, to_pil_image

class fetal_dataset(Dataset):
    def __init__(self, path2data, transform=None):      

        imgsList = [pp for pp in os.listdir(path2data) if "Annotation" not in pp]
        anntsList = [pp for pp in os.listdir(path2train) if "Annotation" in pp]

        self.path2imgs = [os.path.join(path2data, fn) for fn in imgsList] 
        self.path2annts = [p2i.replace(".png", "_Annotation.png") for p2i in self.path2imgs]

        self.transform = transform
    
    def __len__(self):
        return len(self.path2imgs)
      
    def __getitem__(self, idx):
        path2img = self.path2imgs[idx]
        image = Image.open(path2img)

        path2annt = self.path2annts[idx]
        annt_edges = Image.open(path2annt)
        mask = ndi.binary_fill_holes(annt_edges)        
        
        image = np.array(image)
        mask = mask.astype("uint8")        

        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask = augmented['mask']            

        image = to_tensor(image)            
        mask = 255*to_tensor(mask)            
        return image, mask

# %%
fetal_ds1 = fetal_dataset(path2train, transform=transform_train)
fetal_ds2 = fetal_dataset(path2train, transform=transform_val)
print(len(fetal_ds1))
print(len(fetal_ds2))
# Out:
# 999
# 999

# %%
img,mask = fetal_ds1[0]
print(img.shape, img.type(),torch.max(img))
print(mask.shape, mask.type(),torch.max(mask))
# Out:
# torch.Size([1, 128, 192]) torch.FloatTensor tensor(0.9529)
# torch.Size([1, 128, 192]) torch.FloatTensor tensor(1.)

# %%
show_img_mask(img, mask)

# %% [markdown]
# ### Split data into train validation

# %%
from sklearn.model_selection import ShuffleSplit

sss = ShuffleSplit(n_splits=1, test_size=0.2, random_state=0)

indices = range(len(fetal_ds1))

for train_index, val_index in sss.split(indices):
    print(len(train_index))
    print("-"*10)
    print(len(val_index))
# Out:
# 799
# ----------
# 200

# %%
from torch.utils.data import Subset

train_ds = Subset(fetal_ds1,train_index)
print(len(train_ds))

val_ds = Subset(fetal_ds2,val_index)
print(len(val_ds))
# Out:
# 799
# 200

# %%
plt.figure(figsize=(5,5))
for img,mask in train_ds:
    show_img_mask(img,mask)
    break

# %%
plt.figure(figsize=(5,5))
for img,mask in val_ds:
    show_img_mask(img,mask)
    break

# %% [markdown]
# ### Creating DataLoader

# %%
from torch.utils.data import DataLoader
train_dl = DataLoader(train_ds, batch_size=8, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=16, shuffle=False)

# %%
for img_b, mask_b in train_dl:
    print(img_b.shape,img_b.dtype)
    print(mask_b.shape, mask_b.dtype)
    break
# Out:
# torch.Size([8, 1, 128, 192]) torch.float32
# torch.Size([8, 1, 128, 192]) torch.float32

# %%
for img_b, mask_b in val_dl:
    print(img_b.shape,img_b.dtype)
    print(mask_b.shape, mask_b.dtype)
    break
# Out:
# torch.Size([16, 1, 128, 192]) torch.float32
# torch.Size([16, 1, 128, 192]) torch.float32

# %%
torch.max(img_b)
# Out:
# tensor(0.9529)

# %% [markdown]
# ## Creating the Model

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class SegNet(nn.Module):
    def __init__(self, params):
        super(SegNet, self).__init__()
        
        C_in, H_in, W_in = params["input_shape"]
        init_f = params["initial_filters"] 
        num_outputs = params["num_outputs"] 

        self.conv1 = nn.Conv2d(C_in, init_f, kernel_size=3,stride=1,padding=1)
        self.conv2 = nn.Conv2d(init_f, 2*init_f, kernel_size=3,stride=1,padding=1)
        self.conv3 = nn.Conv2d(2*init_f, 4*init_f, kernel_size=3,padding=1)
        self.conv4 = nn.Conv2d(4*init_f, 8*init_f, kernel_size=3,padding=1)
        self.conv5 = nn.Conv2d(8*init_f, 16*init_f, kernel_size=3,padding=1)

        self.upsample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)

        self.conv_up1 = nn.Conv2d(16*init_f, 8*init_f, kernel_size=3,padding=1)
        self.conv_up2 = nn.Conv2d(8*init_f, 4*init_f, kernel_size=3,padding=1)
        self.conv_up3 = nn.Conv2d(4*init_f, 2*init_f, kernel_size=3,padding=1)
        self.conv_up4 = nn.Conv2d(2*init_f, init_f, kernel_size=3,padding=1)

        self.conv_out = nn.Conv2d(init_f, num_outputs , kernel_size=3,padding=1)    
    
    def forward(self, x):
        
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)

        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)

        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2, 2)

        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2, 2)

        x = F.relu(self.conv5(x))

        x = self.upsample(x)
        x = F.relu(self.conv_up1(x))

        x = self.upsample(x)
        x = F.relu(self.conv_up2(x))
        
        x = self.upsample(x)
        x = F.relu(self.conv_up3(x))
        
        x = self.upsample(x)
        x = F.relu(self.conv_up4(x))

        x = self.conv_out(x)
        
        return x

# %%
params_model = {
        "input_shape": (1,h,w),
        "initial_filters": 16, 
        "num_outputs": 1,
            }

model = SegNet(params_model)

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# %%
print(model)
# Out:
# SegNet(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   (conv_up1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_up2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_up3): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_up4): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_out): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
from torchsummary import summary
summary(model, input_size=(1, h, w))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 128, 192]             160
#             Conv2d-2           [-1, 32, 64, 96]           4,640
#             Conv2d-3           [-1, 64, 32, 48]          18,496
#             Conv2d-4          [-1, 128, 16, 24]          73,856
#             Conv2d-5           [-1, 256, 8, 12]         295,168
#           Upsample-6          [-1, 256, 16, 24]               0
#             Conv2d-7          [-1, 128, 16, 24]         295,040
#           Upsample-8          [-1, 128, 32, 48]               0
#             Conv2d-9           [-1, 64, 32, 48]          73,792
#          Upsample-10           [-1, 64, 64, 96]               0
#            Conv2d-11           [-1, 32, 64, 96]          18,464
#          Upsample-12         [-1, 32, 128, 192]               0
#            Conv2d-13         [-1, 16, 128, 192]           4,624
#            Conv2d-14          [-1, 1, 128, 192]             145
# ================================================================
# Total params: 784,385
# Trainable params: 784,385
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.09
# Forward/backward pass size (MB): 22.88
# Params size (MB): 2.99
# Estimated Total Size (MB): 25.96
# ----------------------------------------------------------------

# %% [markdown]
# ## Define Loss Function

# %%
def dice_loss(pred, target, smooth = 1e-5):

    intersection = (pred * target).sum(dim=(2,3))
    union= pred.sum(dim=(2,3)) + target.sum(dim=(2,3)) 
    
    dice= 2.0 * (intersection + smooth) / (union+ smooth)    
    loss = 1.0 - dice
    
    return loss.sum(), dice.sum()

# %%
import torch.nn.functional as F

def loss_func(pred, target):
    bce = F.binary_cross_entropy_with_logits(pred, target,  reduction='sum')
    
    pred = torch.sigmoid(pred)
    dlv, _ = dice_loss(pred, target)
    
    loss = bce  + dlv

    return loss

# %%
for img_v,mask_v in val_dl:
    mask_v = mask_v[8:]
    break

for img_t,mask_t in train_dl:
    break
    
print(dice_loss(mask_v,mask_v))
loss_func(mask_v,torch.zeros_like(mask_v))
# Out:
# (tensor(0.), tensor(8.))
# tensor(173005.1562)

# %%
import torchvision

def metrics_batch(pred, target):
    pred = torch.sigmoid(pred)
    _, metric = dice_loss(pred, target)
    
    return metric

# %%
def loss_batch(loss_func, output, target, opt=None):   
    loss = loss_func(output, target)
    
    with torch.no_grad():
        pred = torch.sigmoid(output)
        _, metric_b = dice_loss(pred, target)
    
    if opt is not None:
        opt.zero_grad()
        loss.backward()
        opt.step()

    return loss.item(), metric_b

# %% [markdown]
# ## Optimizer

# %%
from torch import optim
opt = optim.Adam(model.parameters(), lr=3e-4)

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min',factor=0.5, patience=20,verbose=1)

# %%
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']

current_lr = get_lr(opt)
print('current lr={}'.format(current_lr))
# Out:
# current lr=0.0003

# %% [markdown]
# ## Training the Model

# %%
def loss_epoch(model,loss_func,dataset_dl,sanity_check=False,opt=None):
    running_loss = 0.0
    running_metric = 0.0
    len_data = len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb = xb.to(device)
        yb = yb.to(device)
        
        output = model(xb)
        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)
        running_loss += loss_b
        
        if metric_b is not None:
            running_metric += metric_b

        if sanity_check is True:
            break
    
    loss = running_loss/float(len_data)
    
    metric = running_metric/float(len_data)
    
    return loss, metric

# %%
import copy
def train_val(model, params):
    num_epochs = params["num_epochs"]
    loss_func = params["loss_func"]
    opt = params["optimizer"]
    train_dl = params["train_dl"]
    val_dl = params["val_dl"]
    sanity_check = params["sanity_check"]
    lr_scheduler = params["lr_scheduler"]
    path2weights = params["path2weights"]

    loss_history = {
        "train": [],
        "val": []}
    
    metric_history = {
        "train": [],
        "val": []}    
    
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = float('inf')    
    
    for epoch in range(num_epochs):
        current_lr = get_lr(opt)
        print('Epoch {}/{}, current lr={}'.format(epoch, num_epochs - 1, current_lr))   

        model.train()
        train_loss, train_metric = loss_epoch(model,loss_func,train_dl,sanity_check,opt)

        loss_history["train"].append(train_loss)
        metric_history["train"].append(train_metric)
        
        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model,loss_func,val_dl,sanity_check)
       
        loss_history["val"].append(val_loss)
        metric_history["val"].append(val_metric)   
        
        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            
            torch.save(model.state_dict(), path2weights)
            print("Copied best model weights!")
            
        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print("Loading best model weights!")
            model.load_state_dict(best_model_wts) 
            
        print("train loss: %.6f, dice: %.2f" %(train_loss,100*train_metric))
        print("val loss: %.6f, dice: %.2f" %(val_loss,100*val_metric))
        print("-"*10) 
        

    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %%
opt = optim.Adam(model.parameters(), lr=3e-4)
lr_scheduler = ReduceLROnPlateau(opt, mode='min',factor=0.5, patience=20,verbose=1)

path2models = "./models/"
if not os.path.exists(path2models):
        os.mkdir(path2models)

params_train = {
    "num_epochs": 100,
    "optimizer": opt,
    "loss_func": loss_func,
    "train_dl": train_dl,
    "val_dl": val_dl,
    "sanity_check": False,
    "lr_scheduler": lr_scheduler,
    "path2weights": path2models + "weights.pt",
}

model, loss_hist, metric_hist = train_val(model,params_train)
# Out:
# Epoch 0/99, current lr=0.0003
# Copied best model weights!
# train loss: 11961.873118, dice: 42.28
# val loss: 7094.750430, dice: 63.29
# ----------
# Epoch 1/99, current lr=0.0003
# Copied best model weights!
# train loss: 6158.815128, dice: 71.07
# val loss: 5003.259980, dice: 73.92
# ----------
# Epoch 2/99, current lr=0.0003
# Copied best model weights!
# train loss: 4884.426661, dice: 76.47
# val loss: 4296.338555, dice: 80.13
# ----------
# Epoch 3/99, current lr=0.0003
# Copied best model weights!
# train loss: 3974.865132, dice: 80.28
# val loss: 4067.548965, dice: 79.70
# ----------
# Epoch 4/99, current lr=0.0003
# Copied best model weights!
# train loss: 3472.891889, dice: 82.45
# val loss: 3989.978574, dice: 82.10
# ----------
# Epoch 5/99, current lr=0.0003
# Copied best model weights!
# train loss: 3092.695569, dice: 84.11
# val loss: 2932.729961, dice: 86.03
# ----------
# Epoch 6/99, current lr=0.0003
# Copied best model weights!
# train loss: 2644.631753, dice: 86.30
# val loss: 2630.322178, dice: 88.22
# ----------
# Epoch 7/99, current lr=0.0003
# Copied best model weights!
# train loss: 2339.077920, dice: 87.72
# val loss: 2543.173174, dice: 88.81
# ----------
# Epoch 8/99, current lr=0.0003
# Copied best model weights!
# train loss: 2051.929823, dice: 89.33
# val loss: 2296.866436, dice: 89.72
# ----------
# Epoch 9/99, current lr=0.0003
# Copied best model weights!
# train loss: 1852.814709, dice: 90.38
# val loss: 2180.467266, dice: 90.40
# ----------
# Epoch 10/99, current lr=0.0003
# Copied best model weights!
# train loss: 1737.686556, dice: 91.03
# val loss: 2143.255918, dice: 90.92
# ----------
# Epoch 11/99, current lr=0.0003
# Copied best model weights!
# train loss: 1688.023248, dice: 91.31
# val loss: 2000.707109, dice: 91.81
# ----------
# Epoch 12/99, current lr=0.0003
# Copied best model weights!
# train loss: 1571.786484, dice: 92.11
# val loss: 1910.243525, dice: 90.81
# ----------
# Epoch 13/99, current lr=0.0003
# Copied best model weights!
# train loss: 1500.140621, dice: 92.36
# val loss: 1873.998311, dice: 91.66
# ----------
# Epoch 14/99, current lr=0.0003
# train loss: 1492.525875, dice: 92.51
# val loss: 1910.520244, dice: 91.49
# ----------
# Epoch 15/99, current lr=0.0003
# train loss: 1445.343312, dice: 92.67
# val loss: 1907.594619, dice: 92.42
# ----------
# Epoch 16/99, current lr=0.0003
# train loss: 1364.919102, dice: 93.15
# val loss: 1985.059629, dice: 92.24
# ----------
# Epoch 17/99, current lr=0.0003
# train loss: 1349.011391, dice: 93.34
# val loss: 1920.852979, dice: 92.36
# ----------
# Epoch 18/99, current lr=0.0003
# Copied best model weights!
# train loss: 1366.836010, dice: 93.03
# val loss: 1861.768652, dice: 92.82
# ----------
# Epoch 19/99, current lr=0.0003
# Copied best model weights!
# train loss: 1277.624604, dice: 93.60
# val loss: 1796.725132, dice: 93.11
# ----------
# Epoch 20/99, current lr=0.0003
# train loss: 1222.959694, dice: 93.91
# val loss: 1814.278926, dice: 93.20
# ----------
# Epoch 21/99, current lr=0.0003
# Copied best model weights!
# train loss: 1232.907758, dice: 93.97
# val loss: 1793.780859, dice: 92.89
# ----------
# Epoch 22/99, current lr=0.0003
# train loss: 1252.419280, dice: 93.92
# val loss: 1894.940454, dice: 93.13
# ----------
# Epoch 23/99, current lr=0.0003
# Copied best model weights!
# train loss: 1179.986999, dice: 94.18
# val loss: 1779.160659, dice: 93.23
# ----------
# Epoch 24/99, current lr=0.0003
# train loss: 1181.805358, dice: 94.09
# val loss: 1811.053457, dice: 93.21
# ----------
# Epoch 25/99, current lr=0.0003
# Copied best model weights!
# train loss: 1158.824845, dice: 94.21
# val loss: 1669.840767, dice: 93.01
# ----------
# Epoch 26/99, current lr=0.0003
# train loss: 1153.251427, dice: 94.46
# val loss: 1757.539600, dice: 93.77
# ----------
# Epoch 27/99, current lr=0.0003
# train loss: 1077.353462, dice: 94.66
# val loss: 1852.946294, dice: 93.49
# ----------
# Epoch 28/99, current lr=0.0003
# train loss: 1090.896501, dice: 94.53
# val loss: 1754.176001, dice: 93.55
# ----------
# Epoch 29/99, current lr=0.0003
# train loss: 1086.569657, dice: 94.70
# val loss: 1847.439912, dice: 92.14
# ----------
# Epoch 30/99, current lr=0.0003
# train loss: 1122.123788, dice: 94.47
# val loss: 1705.303115, dice: 93.11
# ----------
# Epoch 31/99, current lr=0.0003
# train loss: 1077.553386, dice: 94.66
# val loss: 1701.348057, dice: 93.75
# ----------
# Epoch 32/99, current lr=0.0003
# train loss: 1018.002463, dice: 95.05
# val loss: 1741.809653, dice: 93.25
# ----------
# Epoch 33/99, current lr=0.0003
# train loss: 1004.114799, dice: 94.95
# val loss: 1725.460674, dice: 93.81
# ----------
# Epoch 34/99, current lr=0.0003
# train loss: 1003.306716, dice: 95.04
# val loss: 1782.790771, dice: 93.46
# ----------
# Epoch 35/99, current lr=0.0003
# train loss: 1056.230898, dice: 94.79
# val loss: 1825.495605, dice: 93.74
# ----------
# Epoch 36/99, current lr=0.0003
# train loss: 942.611338, dice: 95.22
# val loss: 1790.288965, dice: 93.92
# ----------
# Epoch 37/99, current lr=0.0003
# train loss: 972.995429, dice: 95.26
# val loss: 1709.627231, dice: 93.42
# ----------
# Epoch 38/99, current lr=0.0003
# train loss: 901.103683, dice: 95.40
# val loss: 1848.949648, dice: 93.91
# ----------
# Epoch 39/99, current lr=0.0003
# train loss: 885.766969, dice: 95.52
# val loss: 1831.058062, dice: 94.02
# ----------
# Epoch 40/99, current lr=0.0003
# train loss: 1017.033753, dice: 94.94
# val loss: 1823.995322, dice: 94.13
# ----------
# Epoch 41/99, current lr=0.0003
# train loss: 890.847473, dice: 95.57
# val loss: 1700.653555, dice: 93.67
# ----------
# Epoch 42/99, current lr=0.0003
# train loss: 875.496931, dice: 95.55
# val loss: 1914.664297, dice: 94.21
# ----------
# Epoch 43/99, current lr=0.0003
# train loss: 853.676174, dice: 95.66
# val loss: 1826.782798, dice: 94.00
# ----------
# Epoch 44/99, current lr=0.0003
# train loss: 836.273181, dice: 95.79
# val loss: 2090.795405, dice: 93.69
# ----------
# Epoch 45/99, current lr=0.0003
# train loss: 1009.121956, dice: 95.08
# val loss: 1888.102383, dice: 93.56
# ----------
# Epoch 46/99, current lr=0.0003
# Epoch 00047: reducing learning rate of group 0 to 1.5000e-04.
# Loading best model weights!
# train loss: 862.010376, dice: 95.60
# val loss: 1833.523838, dice: 94.31
# ----------
# Epoch 47/99, current lr=0.00015
# train loss: 1106.678761, dice: 94.57
# val loss: 1683.048657, dice: 93.60
# ----------
# Epoch 48/99, current lr=0.00015
# train loss: 1047.497461, dice: 94.77
# val loss: 1841.732534, dice: 93.30
# ----------
# Epoch 49/99, current lr=0.00015
# train loss: 1054.626164, dice: 94.81
# val loss: 1711.478208, dice: 93.78
# ----------
# Epoch 50/99, current lr=0.00015
# train loss: 1029.906348, dice: 94.98
# val loss: 1737.048120, dice: 93.71
# ----------
# Epoch 51/99, current lr=0.00015
# Copied best model weights!
# train loss: 1019.861056, dice: 94.99
# val loss: 1663.168608, dice: 93.60
# ----------
# Epoch 52/99, current lr=0.00015
# train loss: 969.003573, dice: 95.03
# val loss: 1693.200278, dice: 93.75
# ----------
# Epoch 53/99, current lr=0.00015
# train loss: 985.438279, dice: 95.17
# val loss: 1760.795923, dice: 93.75
# ----------
# Epoch 54/99, current lr=0.00015
# train loss: 980.269316, dice: 95.29
# val loss: 1875.368423, dice: 92.32
# ----------
# Epoch 55/99, current lr=0.00015
# train loss: 1012.841395, dice: 94.92
# val loss: 1676.293184, dice: 93.47
# ----------
# Epoch 56/99, current lr=0.00015
# train loss: 975.912321, dice: 95.18
# val loss: 1739.808530, dice: 93.60
# ----------
# Epoch 57/99, current lr=0.00015
# train loss: 926.991286, dice: 95.30
# val loss: 1716.067451, dice: 93.88
# ----------
# Epoch 58/99, current lr=0.00015
# train loss: 896.652832, dice: 95.57
# val loss: 1707.776621, dice: 93.39
# ----------
# Epoch 59/99, current lr=0.00015
# train loss: 896.475135, dice: 95.45
# val loss: 1836.837432, dice: 94.20
# ----------
# Epoch 60/99, current lr=0.00015
# train loss: 889.702745, dice: 95.58
# val loss: 1726.785508, dice: 94.04
# ----------
# Epoch 61/99, current lr=0.00015
# train loss: 903.080164, dice: 95.55
# val loss: 1802.287861, dice: 94.01
# ----------
# Epoch 62/99, current lr=0.00015
# train loss: 872.531470, dice: 95.61
# val loss: 1852.982773, dice: 94.07
# ----------
# Epoch 63/99, current lr=0.00015
# train loss: 831.821796, dice: 95.77
# val loss: 1895.741201, dice: 94.17
# ----------
# Epoch 64/99, current lr=0.00015
# train loss: 824.659296, dice: 95.81
# val loss: 1876.775400, dice: 94.01
# ----------
# Epoch 65/99, current lr=0.00015
# train loss: 856.700829, dice: 95.75
# val loss: 1902.932383, dice: 93.06
# ----------
# Epoch 66/99, current lr=0.00015
# train loss: 857.702485, dice: 95.63
# val loss: 1927.865479, dice: 94.13
# ----------
# Epoch 67/99, current lr=0.00015
# train loss: 820.088805, dice: 95.89
# val loss: 1853.764712, dice: 93.88
# ----------
# Epoch 68/99, current lr=0.00015
# train loss: 830.265015, dice: 95.85
# val loss: 1937.903042, dice: 93.68
# ----------
# Epoch 69/99, current lr=0.00015
# train loss: 888.972429, dice: 95.53
# val loss: 1937.207124, dice: 94.32
# ----------
# Epoch 70/99, current lr=0.00015
# train loss: 779.264205, dice: 96.05
# val loss: 1919.923477, dice: 94.08
# ----------
# Epoch 71/99, current lr=0.00015
# train loss: 790.307284, dice: 95.99
# val loss: 1936.072183, dice: 93.93
# ----------
# Epoch 72/99, current lr=0.00015
# Epoch 00073: reducing learning rate of group 0 to 7.5000e-05.
# Loading best model weights!
# train loss: 772.476678, dice: 96.07
# val loss: 2111.798062, dice: 94.27
# ----------
# Epoch 73/99, current lr=7.5e-05
# train loss: 947.651678, dice: 95.27
# val loss: 1692.690625, dice: 93.85
# ----------
# Epoch 74/99, current lr=7.5e-05
# train loss: 916.115014, dice: 95.44
# val loss: 1722.398872, dice: 93.98
# ----------
# Epoch 75/99, current lr=7.5e-05
# train loss: 894.387626, dice: 95.48
# val loss: 1768.834653, dice: 94.07
# ----------
# Epoch 76/99, current lr=7.5e-05
# train loss: 984.161770, dice: 95.13
# val loss: 1766.427231, dice: 94.11
# ----------
# Epoch 77/99, current lr=7.5e-05
# train loss: 917.357685, dice: 95.51
# val loss: 1750.822466, dice: 94.06
# ----------
# Epoch 78/99, current lr=7.5e-05
# train loss: 911.574025, dice: 95.46
# val loss: 1721.500693, dice: 94.10
# ----------
# Epoch 79/99, current lr=7.5e-05
# train loss: 900.073020, dice: 95.54
# val loss: 1760.008984, dice: 94.10
# ----------
# Epoch 80/99, current lr=7.5e-05
# Copied best model weights!
# train loss: 877.110534, dice: 95.71
# val loss: 1646.965029, dice: 93.78
# ----------
# Epoch 81/99, current lr=7.5e-05
# train loss: 886.026107, dice: 95.56
# val loss: 1725.559473, dice: 94.13
# ----------
# Epoch 82/99, current lr=7.5e-05
# train loss: 863.948102, dice: 95.66
# val loss: 1771.970098, dice: 94.18
# ----------
# Epoch 83/99, current lr=7.5e-05
# train loss: 873.436659, dice: 95.68
# val loss: 1688.859712, dice: 93.83
# ----------
# Epoch 84/99, current lr=7.5e-05
# train loss: 856.025598, dice: 95.71
# val loss: 1670.115327, dice: 93.93
# ----------
# Epoch 85/99, current lr=7.5e-05
# train loss: 838.451931, dice: 95.73
# val loss: 1821.466250, dice: 94.21
# ----------
# Epoch 86/99, current lr=7.5e-05
# train loss: 861.149771, dice: 95.76
# val loss: 1746.175381, dice: 93.83
# ----------
# Epoch 87/99, current lr=7.5e-05
# train loss: 852.741778, dice: 95.74
# val loss: 1808.049155, dice: 94.08
# ----------
# Epoch 88/99, current lr=7.5e-05
# train loss: 824.508557, dice: 95.87
# val loss: 1801.197612, dice: 94.21
# ----------
# Epoch 89/99, current lr=7.5e-05
# train loss: 829.302821, dice: 95.81
# val loss: 1833.522368, dice: 94.05
# ----------
# Epoch 90/99, current lr=7.5e-05
# train loss: 800.580052, dice: 95.96
# val loss: 1881.284292, dice: 94.30
# ----------
# Epoch 91/99, current lr=7.5e-05
# train loss: 809.407539, dice: 95.91
# val loss: 1909.818208, dice: 94.34
# ----------
# Epoch 92/99, current lr=7.5e-05
# train loss: 786.396466, dice: 96.01
# val loss: 1863.652607, dice: 94.25
# ----------
# Epoch 93/99, current lr=7.5e-05
# train loss: 788.385213, dice: 96.07
# val loss: 1876.768247, dice: 94.14
# ----------
# Epoch 94/99, current lr=7.5e-05
# train loss: 779.780406, dice: 96.00
# val loss: 1951.227139, dice: 94.37
# ----------
# Epoch 95/99, current lr=7.5e-05
# train loss: 782.302460, dice: 96.04
# val loss: 1985.204761, dice: 94.33
# ----------
# Epoch 96/99, current lr=7.5e-05
# train loss: 750.467221, dice: 96.19
# val loss: 1928.250874, dice: 94.30
# ----------
# Epoch 97/99, current lr=7.5e-05
# train loss: 768.041657, dice: 96.11
# val loss: 1952.896802, dice: 94.36
# ----------
# Epoch 98/99, current lr=7.5e-05
# train loss: 766.355208, dice: 96.18
# val loss: 1946.103213, dice: 94.11
# ----------
# Epoch 99/99, current lr=7.5e-05
# train loss: 751.962943, dice: 96.23
# val loss: 1972.482295, dice: 94.34
# ----------

# %%
num_epochs = params_train["num_epochs"]

plt.title("Train-Val Loss")
plt.plot(range(1,num_epochs + 1),loss_hist["train"],label="train")
plt.plot(range(1,num_epochs + 1),loss_hist["val"],label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %%
# plot accuracy progress
plt.title("Train-Val Accuracy")
plt.plot(range(1, num_epochs + 1), metric_hist["train"], label="train")
plt.plot(range(1, num_epochs + 1), metric_hist["val"], label="val")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[92], line 4
#       1 # plot accuracy progress
#       3 plt.title("Train-Val Accuracy")
# ----> 4 plt.plot(range(1, num_epochs + 1), metric_hist["train"].cpu().data.numpy(), label="train")
#       5 plt.plot(range(1, num_epochs + 1), metric_hist["val"].cpu().data.numpy(), label="val")
#       6 plt.ylabel("Accuracy")
#
# AttributeError: 'list' object has no attribute 'cpu'
